# %% [markdown]
# # Lab 4: Microsoft Agent Framework Workflow 배포
#
# ## 개요 (Overview)
#
# 이 노트북에서는 Microsoft Agent Framework의 Workflow Pattern을 활용한 Multi-Agent 시스템을 Azure Container Apps에 배포합니다.
#
# ### 아키텍처 (Architecture)
#
# ```
# ┌────────────────────────────────────────────────────────────┐
# │        Agent Framework - Workflow Pattern                 │
# │                                                            │
# │  ┌──────────────────────────────────────────┐             │
# │  │        Router Executor                   │             │
# │  │   (AI-based Intent Classification)       │             │
# │  └────┬──────┬────────┬────────────┬────────┘             │
# │       │      │        │            │                      │
# │   ┌───▼──┐ ┌▼───┐  ┌─▼────┐   ┌──▼────────┐             │
# │   │ Tool │ │Research│ │General│ │Orchestrator│            │
# │   │Exec  │ │Executor│ │Executor│ │Executor  │             │
# │   └───┬──┘ └┬───┘  └─┬────┘   └──┬────────┘             │
# │       │     │        │            │                      │
# │   ┌───▼─────▼────────▼────────────▼──────┐               │
# │   │      Workflow Context                │               │
# │   │   (Message Passing & Output)         │               │
# │   └──────────────────────────────────────┘               │
# │                                                            │
# │   External Resources:                                     │
# │   ┌──────────────┐    ┌────────────────┐                 │
# │   │  MCP Server  │    │  Azure AI      │                 │
# │   │  (Tools)     │    │  Search (RAG)  │                 │
# │   └──────────────┘    └────────────────┘                 │
# └────────────────────────────────────────────────────────────┘
# ```
#
# ### 주요 차이점: Foundry Agent vs Agent Framework
#
# | 특성 | Foundry Agent (Lab 3) | Agent Framework (Lab 4) |
# |------|----------------------|-------------------------|
# | **패턴** | Connected Agent (Handoff) | Workflow Executor Pattern |
# | **메시지 흐름** | Thread-based conversation | Workflow Context streaming |
# | **Agent 간 통신** | Agent API 호출 (handoff) | Workflow message routing |
# | **실행 모델** | Synchronous handoff | Async executor graph |
# | **확장성** | Agent 추가 시 handoff 설정 | Executor & Edge 추가 |
# | **추적** | Agent Service 기본 추적 | Custom OpenTelemetry |
# | **상태 관리** | Thread 상태 유지 | Workflow Context 기반 |
# | **복잡도** | 중간 (Azure 관리형) | 낮음 (코드 중심) |
#
# ### Workflow Pattern의 장점
#
# 1. ✅ **유연한 메시지 라우팅**: 단순한 조건문으로 복잡한 흐름 제어
# 2. ✅ **비동기 실행**: Parallel execution 지원 (Orchestrator)
# 3. ✅ **명확한 실행 그래프**: WorkflowBuilder로 시각적 구조 정의
# 4. ✅ **로컬 개발 용이**: Azure 의존성 최소화, 빠른 테스트
# 5. ✅ **커스텀 제어**: 세밀한 오류 처리 및 로깅
#
# ### Python 모듈 구조 (Python Modules)
#
# ```
# src/agent_framework/
# ├── main_agent_workflow.py  - Workflow 정의 및 Executor 구현
# ├── tool_agent.py           - Tool Agent 클래스 (MCP)
# ├── research_agent.py       - Research Agent 클래스 (RAG)
# ├── api_server.py           - FastAPI HTTP 서버
# ├── masking.py              - 마스킹 유틸리티
# └── requirements.txt        - Python 의존성
# ```
#
# ### 학습 목표 (Learning Objectives)
#
# 1. ✅ Microsoft Agent Framework Workflow Pattern 이해
# 2. ✅ Executor 기반 Multi-Agent 구현
# 3. ✅ Workflow Context를 통한 메시지 라우팅
# 4. ✅ Parallel execution (Orchestrator) 패턴
# 5. ✅ Agent Framework 기반 시스템을 ACA에 배포
# 6. ✅ Foundry Agent와 Agent Framework 비교 분석

# %% [markdown]
# ## 1. 환경 설정 및 인증 (Setup & Authentication)

# %%
import sys, subprocess, os, json
import platform

# 운영체제에 따라 PATH 설정
system = platform.system()
if system == 'Darwin':  # macOS
    extra_paths = '/opt/homebrew/bin:/usr/local/bin'
elif system == 'Linux':  # Linux / Codespaces
    extra_paths = '/usr/local/bin:/usr/bin:/home/codespace/.local/bin'
else:  # Windows
    extra_paths = ''

if extra_paths:
    os.environ['PATH'] = extra_paths + ':' + os.environ.get('PATH', '')

def check(cmd, name):
    try:
        result = subprocess.run(cmd, shell=True, capture_output=True, timeout=3, env=os.environ)
        print(f"{'✓' if result.returncode == 0 else '✗'} {name}")
    except Exception as e:
        print(f"✗ {name}")

print("=== Prerequisites Check ===")
print(f"✓ Python {sys.version.split()[0]} ({system})")
check("az --version", "Azure CLI")
check("docker --version", "Docker")
print("="*50)
# Out:
# === Prerequisites Check ===
# ✓ Python 3.13.7 (Darwin)
# ✓ Azure CLI
# ✓ Docker
# ==================================================

# %%
# Azure 인증
print("=== Azure Authentication ===\n🔐 Authenticating...\n")

az = subprocess.run(
    "az login --tenant 16b3c013-d300-468d-ac64-7eda0820b6d3", 
    shell=True, 
    capture_output=True, 
    text=True
)
print(f"{'✅' if az.returncode == 0 else '❌'} Azure CLI")
print("="*50)
# Out:
# === Azure Authentication ===
# 🔐 Authenticating...
#
# ✅ Azure CLI
# ==================================================

# %%
# 설정 파일 로드
config_path = "config.json"
with open(config_path) as f:
    config = json.load(f)

# 환경 변수 설정
RESOURCE_GROUP = config["resource_group"]
LOCATION = config["location"]
PROJECT_CONNECTION_STRING = config["project_connection_string"]
SEARCH_ENDPOINT = config["search_endpoint"]
SEARCH_INDEX = config["search_index"]
CONTAINER_REGISTRY = config["container_registry_endpoint"]
CONTAINER_ENV_ID = config["container_apps_environment_id"]
MCP_ENDPOINT = config.get("mcp_endpoint", "")

# PROJECT_CONNECTION_STRING을 간단한 형식으로 변환
simple_project_conn = PROJECT_CONNECTION_STRING.split(';')[0] if PROJECT_CONNECTION_STRING else ""

print("=== Configuration Loaded ===")
print(f"Resource Group: {RESOURCE_GROUP}")
print(f"Location: {LOCATION}")
print(f"Search Index: {SEARCH_INDEX}")
print(f"MCP Endpoint: {MCP_ENDPOINT if MCP_ENDPOINT else 'Not configured'}")
print(f"Container Registry: {CONTAINER_REGISTRY}")
print("="*50)
# Out:
# === Configuration Loaded ===
# Resource Group: rg-aiagent-ciid4s
# Location: eastus
# Search Index: ai-agent-knowledge-base
# MCP Endpoint: https://mcp-server.bluestone-09016d03.eastus.azurecontainerapps.io
# Container Registry: crpf3kkfblz2ryy.azurecr.io
# ==================================================

# %% [markdown]
# ## 2. Azure AI Search 키 가져오기 (Get Search Key)
#
# Research Agent가 사용할 Azure AI Search 관리 키를 가져옵니다.

# %%
# AI Search 관리 키 가져오기
search_name = config["search_service_name"]

search_key_cmd = f"""
az search admin-key show \
    --resource-group {RESOURCE_GROUP} \
    --service-name {search_name} \
    --query primaryKey -o tsv
"""

result = subprocess.run(search_key_cmd, shell=True, capture_output=True, text=True)
SEARCH_KEY = result.stdout.strip()

if SEARCH_KEY:
    print(f"✅ Search key retrieved: {SEARCH_KEY[:10]}...")
    os.environ['SEARCH_KEY'] = SEARCH_KEY
else:
    print("❌ Failed to retrieve search key")
# Out:
# ✅ Search key retrieved: 7xQ3Bu7vXI...

# %% [markdown]
# ## 3. Agent Framework Container 빌드 및 배포
#
# ### Container 구성
#
# - **프레임워크**: Microsoft Agent Framework (Workflow Pattern)
# - **포트**: 8000
# - **엔드포인트**:
#   - `/health` - Health check
#   - `/` - Agent Framework 상태 정보
#   - `/chat` - Workflow 실행 엔드포인트 (POST)
#
# ### Workflow Executors
#
# - **Router Executor**: AI 기반 의도 분류 및 라우팅
# - **Tool Executor**: MCP 도구 실행
# - **Research Executor**: RAG 기반 지식 검색
# - **General Executor**: 일반 대화
# - **Orchestrator Executor**: 병렬 실행 및 결과 통합
#
# ### 환경 변수 설정
#
# `.env` 파일에 다음 변수들이 자동으로 설정됩니다:
#
# - `AZURE_AI_PROJECT_ENDPOINT` - Azure AI Project 엔드포인트
# - `AZURE_AI_MODEL_DEPLOYMENT_NAME` - 모델 배포 이름 (gpt-4o)
# - `SEARCH_ENDPOINT`, `SEARCH_INDEX` - Azure AI Search 설정
# - `MCP_ENDPOINT` - MCP Server 엔드포인트
# - `APPLICATIONINSIGHTS_CONNECTION_STRING` - Application Insights (Analytics)
# - `OTEL_*` - OpenTelemetry 설정 (Tracing)
# - `AZURE_TRACING_GEN_AI_CONTENT_RECORDING_ENABLED` - Prompt/Completion 기록

# %%
# Container Registry 로그인
registry_name = CONTAINER_REGISTRY.split('.')[0]

print("=== Container Registry Login ===")
login_cmd = f"az acr login --name {registry_name}"
result = subprocess.run(login_cmd, shell=True, capture_output=True, text=True)

if result.returncode == 0:
    print(f"✅ Logged in to {registry_name}")
else:
    print(f"❌ Login failed: {result.stderr}")
print("="*50)
# Out:
# === Container Registry Login ===
# ✅ Logged in to crpf3kkfblz2ryy
# ==================================================

# %%
# .env 파일 생성 (Agent Framework Container용)
print("=== Creating .env file for Agent Framework Container ===\n")

# 1. Application Insights Connection String 가져오기
print("📊 Getting Application Insights connection string...")
appinsights_cmd = f"""
az monitor app-insights component show \
    --resource-group {RESOURCE_GROUP} \
    --query "[0].connectionString" -o tsv
"""

result = subprocess.run(appinsights_cmd, shell=True, capture_output=True, text=True)

if result.returncode == 0 and result.stdout.strip():
    APP_INSIGHTS_CONN_STR = result.stdout.strip()
    print(f"✅ Application Insights connection string retrieved\n")
else:
    print(f"⚠️  Could not get Application Insights connection string")
    print(f"   Proceeding without Application Insights\n")
    APP_INSIGHTS_CONN_STR = ""

# 2. .env 파일 생성
env_content = f"""# Azure AI Project Configuration (Microsoft Agent Framework)
AZURE_AI_PROJECT_ENDPOINT={simple_project_conn}
AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o

# MCP Server Configuration
MCP_ENDPOINT={MCP_ENDPOINT if MCP_ENDPOINT else ''}

# Azure AI Search Configuration (for Research Agent with RAG)
SEARCH_ENDPOINT={SEARCH_ENDPOINT}
SEARCH_INDEX={SEARCH_INDEX}
SEARCH_KEY={SEARCH_KEY}

# Application Insights Configuration (for Application Analytics)
APPLICATIONINSIGHTS_CONNECTION_STRING={APP_INSIGHTS_CONN_STR}

# OpenTelemetry Configuration (for Tracing)
OTEL_SERVICE_NAME=agent-framework-workflow
OTEL_TRACES_EXPORTER=azure_monitor
OTEL_METRICS_EXPORTER=azure_monitor
OTEL_LOGS_EXPORTER=azure_monitor
OTEL_PYTHON_LOGGING_AUTO_INSTRUMENTATION_ENABLED=true
AZURE_TRACING_GEN_AI_CONTENT_RECORDING_ENABLED=true

# Masking / PII Handling
AGENT_MASKING_MODE=standard  # off|standard|strict
"""

env_file_path = "src/agent_framework/.env"

try:
    with open(env_file_path, 'w') as f:
        f.write(env_content)
    
    print(f"✅ Created {env_file_path}")
    print("\n📋 Environment variables:")
    for line in env_content.strip().split('\n'):
        if line and not line.startswith('#'):
            key = line.split('=')[0]
            print(f"   • {key}")
    
    print("\n💡 이 파일은 Docker 이미지에 포함됩니다.")
    
    if APP_INSIGHTS_CONN_STR:
        print("\n✅ Application Insights 설정 완료!")
        print("   → OpenTelemetry Tracing 활성화")
        print("   → GenAI content recording 활성화")
    else:
        print("\n⚠️  Application Insights 미설정")
        print("   → Analytics는 작동하지 않지만 Agent는 정상 작동합니다.")
    
    print(f"\n🔍 Azure AI Search 설정 완료!")
    print(f"   → RAG (Retrieval-Augmented Generation) 활성화")
    print(f"   → Research Agent가 지식 베이스 검색 가능")
    
except Exception as e:
    print(f"❌ Failed to create .env file: {e}")

print("\n" + "="*60)
# Out:
# === Creating .env file for Agent Framework Container ===
#
# 📊 Getting Application Insights connection string...
# ✅ Application Insights connection string retrieved
#
# ✅ Created src/agent_framework/.env
#
# 📋 Environment variables:
#    • AZURE_AI_PROJECT_ENDPOINT
#    • AZURE_AI_MODEL_DEPLOYMENT_NAME
#    • MCP_ENDPOINT
#    • SEARCH_ENDPOINT
#    • SEARCH_INDEX
#    • SEARCH_KEY
#    • APPLICATIONINSIGHTS_CONNECTION_STRING
#    • OTEL_SERVICE_NAME
#    • OTEL_TRACES_EXPORTER
#    • OTEL_METRICS_EXPORTER
#    • OTEL_LOGS_EXPORTER
#    • OTEL_PYTHON_LOGGING_AUTO_INSTRUMENTATION_ENABLED
#    • AZURE_TRACING_GEN_AI_CONTENT_RECORDING_ENABLED
#    • AGENT_MASKING_MODE
#
# 💡 이 파일은 Docker 이미지에 포함됩니다.
#
# ✅ Application Insights 설정 완료!
#    → OpenTelemetry Tracing 활성화
#    → GenAI content recording 활성화
#
# 🔍 Azure AI Search 설정 완료!
#    → RAG (Retrieval-Augmented Generation) 활성화
#    → Research Agent가 지식 베이스 검색 가능
#
# ============================================================

# %%
# Agent Framework Container 이미지 빌드 및 푸시
import time

framework_image = f"{CONTAINER_REGISTRY}/agent-framework:latest"

print("=== Building Agent Framework Image ===")
print(f"Image: {framework_image}\n")

# 빌드 (Azure Container Apps용 linux/amd64 플랫폼)
build_cmd = f"docker build --platform linux/amd64 -t {framework_image} ./src/agent_framework"
print("🔨 Building image (linux/amd64)...")
start_time = time.time()

result = subprocess.run(build_cmd, shell=True, capture_output=True, text=True)
elapsed = time.time() - start_time

if result.returncode == 0:
    print(f"✅ Build successful ({elapsed:.1f}s)")
    print(f"   Framework: Microsoft Agent Framework (Workflow Pattern)")
else:
    print(f"❌ Build failed: {result.stderr}")
    
# 푸시
if result.returncode == 0:
    print("\n📤 Pushing image to registry...")
    push_cmd = f"docker push {framework_image}"
    result = subprocess.run(push_cmd, shell=True, capture_output=True, text=True)
    
    if result.returncode == 0:
        print(f"✅ Push successful")
    else:
        print(f"❌ Push failed: {result.stderr}")

print("="*50)
# Out:
# === Building Agent Framework Image ===
# Image: crpf3kkfblz2ryy.azurecr.io/agent-framework:latest
#
# 🔨 Building image (linux/amd64)...
# ✅ Build successful (1.9s)
#    Framework: Microsoft Agent Framework (Workflow Pattern)
#
# 📤 Pushing image to registry...
# ✅ Push successful
# ==================================================

# %% [markdown]
# ## 4. Azure 리소스 확인 및 Agent Framework Service 배포
#
# Agent Framework Service를 배포하고 **배포 직후 자동으로** Managed Identity를 구성합니다.
#
# ### 자동 수행 작업
#
# 1. ✅ Azure AI Project 리소스 ID 확인
# 2. ✅ Container App 배포 (replicas=0으로 시작)
# 3. ✅ System-assigned Managed Identity 활성화
# 4. ✅ Azure AI User 역할 할당 (AI Project scope)
# 5. ✅ 권한 전파 대기 안내
#
# > 💡 **중요**: 배포와 권한 설정을 한 번에 처리하므로 완료까지 약 3-4분 소요됩니다.

# %%
# Azure AI Project 리소스 ID 확인
print("=== Verifying Azure Resources ===\n")

# URL에서 project_name 추출
if '/api/projects/' in simple_project_conn:
    project_name = simple_project_conn.split('/api/projects/')[-1].strip()
else:
    project_name = None

print(f"📋 Project Information:")
print(f"   Resource Group: {RESOURCE_GROUP}")
print(f"   Project Name: {project_name if project_name else 'Not found'}\n")

# AI Project 리소스 ID 가져오기
print("🔍 Finding AI Project resource...")
if project_name:
    ai_project_cmd = f"""
    az resource list \
        --resource-group {RESOURCE_GROUP} \
        --query "[?contains(name, '{project_name}') && type=='Microsoft.CognitiveServices/accounts/projects'].id" -o tsv
    """
else:
    ai_project_cmd = f"""
    az resource list \
        --resource-group {RESOURCE_GROUP} \
        --query "[?type=='Microsoft.CognitiveServices/accounts/projects'].id | [0]" -o tsv
    """

result = subprocess.run(ai_project_cmd, shell=True, capture_output=True, text=True)
if result.returncode == 0 and result.stdout.strip():
    ai_project_resource_id = result.stdout.strip()
    print(f"   ✅ AI Project Resource ID:")
    print(f"   {ai_project_resource_id}\n")
else:
    print(f"   ❌ Could not find AI Project")
    raise Exception("AI Project not found")

print("✅ All required resources verified!")
print("="*60)
# Out:
# === Verifying Azure Resources ===
#
# 📋 Project Information:
#    Resource Group: rg-aiagent-ciid4s
#    Project Name: proj-pf3kkfblz2ryy
#
# 🔍 Finding AI Project resource...
#    ✅ AI Project Resource ID:
#    /subscriptions/49a89096-a0ae-4e59-816b-dcb0a6fe9168/resourceGroups/rg-aiagent-ciid4s/providers/Microsoft.CognitiveServices/accounts/aoai-pf3kkfblz2ryy/projects/proj-pf3kkfblz2ryy
#
# ✅ All required resources verified!
# ============================================================

# %%
# Agent Framework Service를 Container App으로 배포 + Managed Identity 권한 설정
framework_app_name = "agent-framework"

print("=== Deploying Agent Framework Service to ACA ===")
print(f"App Name: {framework_app_name}\n")

print("💡 환경 변수는 이미 Docker 이미지에 포함되어 있습니다.\n")

# 1. Container App 배포 (Managed Identity 포함, replicas=0)
deploy_cmd = f"""
az containerapp create \
    --name {framework_app_name} \
    --resource-group {RESOURCE_GROUP} \
    --environment {CONTAINER_ENV_ID.split('/')[-1]} \
    --image {framework_image} \
    --target-port 8000 \
    --ingress external \
    --min-replicas 0 \
    --max-replicas 3 \
    --cpu 1.0 \
    --memory 2.0Gi \
    --registry-server {CONTAINER_REGISTRY} \
    --system-assigned \
"""

print("🚀 Deploying Agent Framework Service with Managed Identity...")
print("   (Starting with 0 replicas to configure permissions first)")
result = subprocess.run(deploy_cmd, shell=True, capture_output=True, text=True, timeout=180)

if result.returncode == 0:
    print("✅ Deployment successful\n")
    
    # Get endpoint
    show_cmd = f"""
    az containerapp show \
        --name {framework_app_name} \
        --resource-group {RESOURCE_GROUP} \
        --query properties.configuration.ingress.fqdn -o tsv
    """
    result = subprocess.run(show_cmd, shell=True, capture_output=True, text=True)
    FRAMEWORK_ENDPOINT = f"https://{result.stdout.strip()}"
    
    print(f"🌐 Agent Framework Endpoint: {FRAMEWORK_ENDPOINT}")
    
    # Update config
    config['agent_framework_endpoint'] = FRAMEWORK_ENDPOINT
    with open(config_path, 'w') as f:
        json.dump(config, f, indent=2)
    print("✅ Config updated\n")
    
    # 2. Managed Identity Principal ID 가져오기
    print("="*60)
    print("🔐 Configuring Permissions\n")
    
    print("1️⃣ Getting Managed Identity Principal ID...")
    identity_cmd = f"""
    az containerapp show \
        --name {framework_app_name} \
        --resource-group {RESOURCE_GROUP} \
        --query identity.principalId -o tsv
    """
    
    result = subprocess.run(identity_cmd, shell=True, capture_output=True, text=True)
    if result.returncode == 0 and result.stdout.strip():
        principal_id = result.stdout.strip()
        print(f"   ✅ Principal ID: {principal_id}\n")
    else:
        print(f"   ❌ Failed to get Principal ID\n")
        raise Exception("Failed to get Managed Identity Principal ID")
    
    # 3. Azure AI User 역할 할당
    print("2️⃣ Assigning 'Azure AI User' role to AI Project...")
    print(f"   Scope: {ai_project_resource_id}")
    role_assignment_cmd = f"""
    az role assignment create \
        --assignee {principal_id} \
        --role "Azure AI User" \
        --scope {ai_project_resource_id}
    """
    
    result = subprocess.run(role_assignment_cmd, shell=True, capture_output=True, text=True)
    if result.returncode == 0:
        print("   ✅ Azure AI User role assigned\n")
    elif "already exists" in result.stderr.lower():
        print("   ✅ Azure AI User role already exists\n")
    else:
        print(f"   ❌ Role assignment FAILED!")
        print(f"   Error: {result.stderr}\n")
    
    # 4. 권한 검증
    print("3️⃣ Verifying role assignments...\n")
    import time
    time.sleep(5)
    
    role_check_cmd = f"""
    az role assignment list \
        --assignee {principal_id} \
        --query "[].{{role:roleDefinitionName, scope:scope}}" -o json
    """
    
    result = subprocess.run(role_check_cmd, shell=True, capture_output=True, text=True)
    if result.returncode == 0:
        import json as json_lib
        current_roles = json_lib.loads(result.stdout)
        
        print(f"   📋 Current Role Assignments ({len(current_roles)} total):\n")
        
        required_roles = {"Azure AI User (AI Project)": False}
        
        for role in current_roles:
            scope_parts = role['scope'].split('/')
            resource_name = scope_parts[-1] if scope_parts else 'Unknown'
            role_name = role['role']
            
            print(f"      • {role_name} → {resource_name}")
            
            if role_name == "Azure AI User":
                if "projects" in role['scope'] or ai_project_resource_id in role['scope']:
                    required_roles["Azure AI User (AI Project)"] = True
        
        print(f"\n   🔍 Required Roles Verification:")
        all_roles_ok = True
        for role_name, assigned in required_roles.items():
            status = "✅" if assigned else "❌"
            print(f"      {status} {role_name}")
            if not assigned:
                all_roles_ok = False
        
        if all_roles_ok:
            print(f"\n   ✅ All required roles are assigned!\n")
        else:
            print(f"\n   ❌ Some required roles are missing!\n")
    
    # 5. 권한 전파 대기 안내
    print("="*60)
    print("4️⃣ Permissions assigned - waiting for propagation...\n")
    print("⚠️  Azure RBAC 권한 전파는 최대 5-10분 소요될 수 있습니다.")
    print("   Container는 replicas=0 상태로 유지됩니다.\n")
    
    print("📋 다음 단계:")
    print("   1. 위의 'Required Roles Verification'이 모두 ✅인지 확인")
    print("   2. 2-3분 정도 기다리세요")
    print("   3. 다음 셀(섹션 5)을 실행하여 Container를 시작하세요")
    
    print("\n" + "="*60)
    print("✅ Permissions configured successfully!")
    print(f"\n🌐 Endpoint: {FRAMEWORK_ENDPOINT}")
    print(f"\n⏳ 권한 전파를 기다린 후 다음 셀을 실행하세요!")
else:
    print(f"❌ Deployment failed: {result.stderr}")
    FRAMEWORK_ENDPOINT = None

print("\n" + "="*60)
# Out:
# === Deploying Agent Framework Service to ACA ===
# App Name: agent-framework
#
# 💡 환경 변수는 이미 Docker 이미지에 포함되어 있습니다.
#
# 🚀 Deploying Agent Framework Service with Managed Identity...
#    (Starting with 0 replicas to configure permissions first)
# ✅ Deployment successful
#
# 🌐 Agent Framework Endpoint: https://agent-framework.bluestone-09016d03.eastus.azurecontainerapps.io
# ✅ Config updated
#
# ============================================================
# 🔐 Configuring Permissions
#
# 1️⃣ Getting Managed Identity Principal ID...
#    ✅ Principal ID: 04dff71f-29bc-449d-a902-c2082e58d47d
#
# 2️⃣ Assigning 'Azure AI User' role to AI Project...
#    Scope: /subscriptions/49a89096-a0ae-4e59-816b-dcb0a6fe9168/resourceGroups/rg-aiagent-ciid4s/providers/Microsoft.CognitiveServices/accounts/aoai-pf3kkfblz2ryy/projects/proj-pf3kkfblz2ryy
#    ✅ Azure AI User role assigned
#
# 3️⃣ Verifying role assignments...
#
#    📋 Current Role Assignments (0 total):
#
#
#    🔍 Required Roles Verification:
#       ❌ Azure AI User (AI Project)
#
#    ❌ Some required roles are missing!
#
# ============================================================
# 4️⃣ Permissions assigned - waiting for propagation...
#
# ⚠️  Azure RBAC 권한 전파는 최대 5-10분 소요될 수 있습니다.
#    Container는 replicas=0 상태로 유지됩니다.
#
# 📋 다음 단계:
#    1. 위의 'Required Roles Verification'이 모두 ✅인지 확인
#    2. 2-3분 정도 기다리세요
#    3. 다음 셀(섹션 5)을 실행하여 Container를 시작하세요
#
# ============================================================
# ✅ Permissions configured successfully!
#
# 🌐 Endpoint: https://agent-framework.bluestone-09016d03.eastus.azurecontainerapps.io
#
# ⏳ 권한 전파를 기다린 후 다음 셀을 실행하세요!
#
# ============================================================

# %% [markdown]
# ## 5. Agent Framework Service 시작 (Start Service)
#
# 권한 전파가 완료된 후 이 셀을 실행하여 Container를 시작합니다.
#
# **실행 시점:**
# - ⏰ 섹션 4 완료 후 **2-3분 대기**
# - ⚠️ 권한 오류 발생 시: 추가로 2-3분 더 기다린 후 재실행

# %%
# replicas를 1로 확장
scale_cmd = f"""
az containerapp update \
    --name {framework_app_name} \
    --resource-group {RESOURCE_GROUP} \
    --min-replicas 1 \
    --max-replicas 1
"""

print("🚀 Scaling to 1 replica...")
result = subprocess.run(scale_cmd, shell=True, capture_output=True, text=True, timeout=120)

if result.returncode == 0:
    print("✅ Agent Framework Service started successfully!")
    print(f"\n🌐 Endpoint: {FRAMEWORK_ENDPOINT}")
    print("\n💡 Container가 시작되는 데 약 30초 정도 소요됩니다.")
    print(f"   로그 확인: az containerapp logs show --name {framework_app_name} --resource-group {RESOURCE_GROUP} --tail 50")
else:
    print(f"❌ Failed to start: {result.stderr}")

print("\n" + "="*60)
# Out:
# 🚀 Scaling to 1 replica...
# ✅ Agent Framework Service started successfully!
#
# 🌐 Endpoint: https://agent-framework.bluestone-09016d03.eastus.azurecontainerapps.io
#
# 💡 Container가 시작되는 데 약 30초 정도 소요됩니다.
#    로그 확인: az containerapp logs show --name agent-framework --resource-group rg-aiagent-ciid4s --tail 50
#
# ============================================================

# %% [markdown]
# ## 6. 배포된 Agent Framework 테스트
#
# **⚠️ 중요한 차이점 - Foundry Agent vs Agent Framework:**
#
# **Foundry Agent (Lab 3):**
# - ✅ Application Analytics 자동 수집
# - ✅ Tracing 자동 활성화 (Azure Agent Service 기본 기능)
# - ✅ AI Foundry 포털에서 실행 흐름 확인 가능
#
# **Agent Framework (Lab 4 - 현재):**
# - ❌ Application Analytics **수집 안됨** (OpenTelemetry 미구현)
# - ❌ Tracing **비활성화** (계측 코드 없음)
# - ✅ 컨테이너 로그로만 디버깅 가능
#
# > 💡 **Agent Framework는 코드 중심 접근**으로 유연성을 제공하지만,
# > 모니터링/트레이싱은 **직접 구현**해야 합니다.
# > (requirements.txt의 OpenTelemetry 패키지가 주석 처리되어 있음)
#
# **Workflow 실행 흐름:**
# 1. Router Executor: 의도 분류 (tool/research/orchestrator/general)
# 2. 해당 Executor로 메시지 라우팅
# 3. Workflow Context를 통한 출력 수집
# 4. 통합된 응답 반환

# %%
import requests
import json

print("=== 배포된 Agent Framework Service 테스트 ===\n")

if not FRAMEWORK_ENDPOINT:
    print("❌ FRAMEWORK_ENDPOINT가 설정되지 않았습니다!")
    print("   섹션 4를 먼저 실행하세요.\n")
else:
    print(f"🌐 Agent Framework Endpoint: {FRAMEWORK_ENDPOINT}\n")
    
    # 1. Health check
    print("1️⃣ Health Check:")
    try:
        response = requests.get(f"{FRAMEWORK_ENDPOINT}/health", timeout=10)
        if response.status_code == 200:
            print(f"   ✅ Health: {response.json()}\n")
        else:
            print(f"   ❌ Health check failed: {response.status_code}\n")
    except Exception as e:
        print(f"   ❌ Error: {e}\n")
    
    # 2. Root endpoint 확인
    print("2️⃣ Agent Framework Status:")
    try:
        response = requests.get(f"{FRAMEWORK_ENDPOINT}/", timeout=10)
        if response.status_code == 200:
            status = response.json()
            print(f"   ✅ Status: {status.get('status')}")
            print(f"   📋 Framework: {status.get('framework')}")
            print(f"   🔧 Agents:")
            for agent_name, available in status.get('agents', {}).items():
                icon = "✅" if available else "❌"
                print(f"      {icon} {agent_name}: {available}")
            print()
        else:
            print(f"   ❌ Status check failed: {response.status_code}\n")
    except Exception as e:
        print(f"   ❌ Error: {e}\n")
    
    print("="*70)
    print("\n💡 Agent Framework Service가 정상 작동 중입니다!")
    print("   다음 셀에서 Workflow 실행을 테스트하세요.\n")
    print("="*70)
# Out:
# === 배포된 Agent Framework Service 테스트 ===
#
# 🌐 Agent Framework Endpoint: https://agent-framework.bluestone-09016d03.eastus.azurecontainerapps.io
#
# 1️⃣ Health Check:
#    ✅ Health: {'status': 'healthy', 'service': 'Agent Framework API Server'}
#
# 2️⃣ Agent Framework Status:
#    ✅ Status: running
#    📋 Framework: Microsoft Agent Framework - Workflow Pattern
#    🔧 Agents:
#       ✅ main_agent_workflow: True
#       ✅ orchestrator: True
#       ✅ tool_routing: True
#       ✅ research_routing: True
#       ✅ general_routing: True
#
# ======================================================================
#
# 💡 Agent Framework Service가 정상 작동 중입니다!
#    다음 셀에서 Workflow 실행을 테스트하세요.
#
# ======================================================================

# %% [markdown]
# ### 6.1. Workflow Pattern 테스트 (다양한 질문)
#
# 배포된 Agent Framework에 다양한 질문을 보내서 Workflow 실행을 테스트합니다.
#
# **Router 의도 분류:**
# - **tool**: 단순 도구 실행 (날씨)
# - **research**: 단순 지식 검색 (RAG)
# - **orchestrator**: 복합 질의 (도구 + 지식)
# - **general**: 일반 대화

# %%
# Agent Framework Workflow 테스트
import requests
import json
import time
import statistics

print("=== Agent Framework Workflow 테스트 ===\n")

# 테스트 케이스 (10개)
test_cases = [
    {
        "message": "서울의 현재 날씨를 알려주세요",
        "description": "Tool Executor (날씨 조회)"
    },
    {
        "message": "RAG 패턴에 대해 설명해주세요",
        "description": "Research Executor (지식 검색)"
    },
    {
        "message": "안녕하세요",
        "description": "General Executor (일반 대화)"
    },
    {
        "message": "Tokyo의 날씨를 알려주고, MCP에 대해서도 설명해주세요",
        "description": "Orchestrator Executor (병렬 실행: Tool + Research)"
    },
    {
        "message": "Paris와 London의 날씨를 비교해주세요",
        "description": "Tool Executor (다중 도시)"
    },
    {
        "message": "Multi-agent orchestration의 best practice는?",
        "description": "Research Executor (베스트 프랙티스)"
    },
    {
        "message": "San Francisco의 날씨와 Azure AI Agent 개발 방법을 알려주세요",
        "description": "Orchestrator Executor (복합 질의)"
    },
    {
        "message": "베이징의 날씨는 어떤가요?",
        "description": "Tool Executor (베이징 날씨)"
    },
    {
        "message": "Agent Framework의 Workflow Pattern이란?",
        "description": "Research Executor (Framework 개념)"
    },
    {
        "message": "시드니의 날씨와 Connected Agent 패턴을 설명해주세요",
        "description": "Orchestrator Executor (날씨 + 패턴)"
    }
]

success_count = 0
fail_count = 0
latencies = []

for i, test in enumerate(test_cases, 1):
    print(f"{'='*70}")
    print(f"[Test {i}/{len(test_cases)}]")
    print(f"질문: {test['message']}")
    print(f"예상 경로: {test['description']}")
    print(f"{'='*70}")
    
    try:
        start_req = time.perf_counter()
        response = requests.post(
            f"{FRAMEWORK_ENDPOINT}/chat",
            json={"message": test['message']},
            headers={"Content-Type": "application/json"},
            timeout=90
        )
        elapsed_req = (time.perf_counter() - start_req) * 1000
        
        if response.status_code == 200:
            result = response.json()
            full_resp = result.get('response', 'No response') or ''
            print(f"\n✅ 응답 성공 (HTTP {response.status_code}) - {elapsed_req:.1f} ms")
            latencies.append(elapsed_req)
            print(f"\n📝 Workflow 응답:")
            print(full_resp)
            print()
            success_count += 1
        else:
            print(f"\n❌ 요청 실패 (HTTP {response.status_code})")
            print(f"오류: {response.text[:200]}")
            print()
            fail_count += 1
        
    except Exception as e:
        print(f"\n❌ 오류 발생: {e}")
        print()
        fail_count += 1
    
    if i < len(test_cases):
        time.sleep(2)

print("="*70)
print(f"\n📊 테스트 결과:")
print(f"   ✅ 성공: {success_count}/{len(test_cases)}")
print(f"   ❌ 실패: {fail_count}/{len(test_cases)}")

if success_count > 0:
    avg_latency = statistics.mean(latencies) if latencies else 0
    p95_latency = (sorted(latencies)[int(len(latencies)*0.95)-1] if len(latencies) >= 2 else latencies[0]) if latencies else 0
    print(f"   ⏱️  평균 지연: {avg_latency:.1f} ms (p95≈{p95_latency:.1f} ms)")
    print(f"\n🎉 {success_count}개의 Workflow 실행이 성공했습니다!")
    print(f"\n⚠️  참고: Agent Framework는 OpenTelemetry가 구현되지 않아")
    print(f"   AI Foundry Analytics/Tracing에 데이터가 수집되지 않습니다.")
    print(f"   디버깅은 컨테이너 로그를 통해 확인하세요:")
    print(f"   az containerapp logs show --name {framework_app_name} --resource-group {RESOURCE_GROUP} --tail 50")
else:
    print(f"\n❌ 모든 요청이 실패했습니다.")
    print(f"   로그 확인: az containerapp logs show --name {framework_app_name} --resource-group {RESOURCE_GROUP} --tail 50")

print("\n" + "="*70)
# Out:
# === Agent Framework Workflow 테스트 ===
#
# ======================================================================
# [Test 1/10]
# 질문: 서울의 현재 날씨를 알려주세요
# 예상 경로: Tool Executor (날씨 조회)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 9815.4 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# 날씨 정보: {
#   "location": "Seoul, South Korea",
#   "temperature": "18°C",
#   "feels_like": "18°C",
#   "condition": "Light rain",
#   "humidity": "100%",
#   "wind_speed": "17 km/h ENE",
#   "observation_time": "09:41 PM",
#   "data_source": "wttr.in (real-time weather data)"
# }
#
# ======================================================================
# [Test 2/10]
# 질문: RAG 패턴에 대해 설명해주세요
# 예상 경로: Research Executor (지식 검색)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 17277.9 ms
#
# 📝 Workflow 응답:
# 📚 [RAG-based Answer]
#
# RAG (Retrieval-Augmented Generation) 패턴은 자연어 처리 분야에서 최신 정보를 생성할 때, 외부 데이터베이스에서 적절한 정보를 검색하여 이를 기초로 응답을 생성하는 기법입니다. 이 패턴은 고품질의 정보 제공을 위해 텍스트 생성 모델에 검색 기능을 추가하는 방식으로 구현됩니다.
#
# Azure AI Search와 같은 검색 시스템과의 통합이 일반적이며, 이를 통해 검색 단계와 생성 단계를 결합하여 더 정확하고 풍부한 정보를 사용자에게 제공할 수 있습니다. 예를 들어, 검색 쿼리를 기반으로 임베딩을 생성하고 이를 통해 문서 또는 정보 인덱스를 검색하는 방식으로 작동합니다. 검색한 정보는 응답을 생성하는 데 필요한 컨텍스트를 제공합니다 [Result 4].
#
# 검색 시스템에서 위의 구현 예제는 Azure OpenAI와 Azure Search를 결합하여 사용됩니다. 먼저 텍스트 입력의 임베딩을 생성하고, 이를 통해 정보 인덱스를 검색합니다. 이후 검색된 결과는 응답 생성에 이용됩니다 [Result 5].
#
# RAG 패턴의 강점은 모델이 단순한 학습 데이터 기반 응답을 넘어 최신 정보를 활용한 응답을 생성할 수 있다는 점에 있습니다. 이를 통해 사용자는 더 유의미하고 신뢰할 수 있는 정보를 제공받을 수 있습니다.
#
# ======================================================================
# [Test 3/10]
# 질문: 안녕하세요
# 예상 경로: General Executor (일반 대화)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 5072.6 ms
#
# 📝 Workflow 응답:
# 💬 안녕하세요! 어떻게 도와드릴까요?
#
# ======================================================================
# [Test 4/10]
# 질문: Tokyo의 날씨를 알려주고, MCP에 대해서도 설명해주세요
# 예상 경로: Orchestrator Executor (병렬 실행: Tool + Research)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 16927.8 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# 날씨 정보: {
#   "location": "Shikinejima, Japan",
#   "temperature": "22°C",
#   "feels_like": "25°C",
#   "condition": "Patchy rain nearby",
#   "humidity": "77%",
#   "wind_speed": "54 km/h NE",
#   "observation_time": "12:48 AM",
#   "data_source": "wttr.in (real-time weather data)"
# }
#
# 📚 [RAG-based Answer]
#
# 1. **Tokyo의 날씨**: 현재 Tokyo의 날씨 정보를 제공하는 방법에 대해서는 직접 검색 결과가 없습니다. 하지만, 일반적으로 MCP의 도구로 구현하여 날씨 정보를 제공할 수 있습니다. 예를 들어, 외부 API를 호출하여 날씨 데이터를 가져오는 Python 함수는 다음과 같습니다:
#
#     ```python
#     from typing import Dict, Any
#
#     def weather_tool(location: str, unit: str = "celsius") -> Dict[str, Any]:
#         """날씨 정보를 가져오는 도구"""
#         # 외부 API 호출 또는 데이터베이스 쿼리
#         weather_data = get_weather_data(location)
#
#         return {
#             "success": True,
#             "location": location,
#             "temperature": weather_data["temp"],
#             "unit": unit,
#             "conditions": weather_data["conditions"]
#         }
#     ```
#
#     이 코드는 특정 위치의 날씨 정보를 반환하는 함수로, 실제 API 호출 로직은 `get_weather_data(location)`을 통해 구현되어야 합니다 [Result 3].
#
# 2. **MCP (Model Context Protocol) 설명**:
#
#    MCP는 여러 도구를 표준 스키마를 통해 정의하는 프로토콜입니다. MCP의 도구는 JSON 스키마를 따르며, 이름, 설명, 그리고 파라미터들을 정의할 수 있습니다 [Result 2]. 도구의 각 요소는 명확하게 정의되고, 필요한 경우 필수 파라미터를 지정할 수 있습니다. 예를 들어:
#
#     ```json
#     {
#         "name": "tool_name",
#         "description": "What the tool does",
#         "parameters": {
#             "type": "object",
#             "properties": {
#                 "param1": {
#                     "type": "string",
#                     "description": "Parameter description"
#                 }
#             },
#             "required": ["param1"]
#         }
#     }
#     ```
#
#    MCP는 도구 명명, 파라미터 검증, 에러 처리, 상세 문서화, 버전 관리, 모니터링, 타임아웃, 보안 등의 베스트 프랙티스를 권장합니다. 이를 통해 안정적이고 확장 가능하며 안전한 도구를 개발할 수 있습니다 [Result 1].
#
# ======================================================================
# [Test 5/10]
# 질문: Paris와 London의 날씨를 비교해주세요
# 예상 경로: Tool Executor (다중 도시)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 7623.6 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# {"tool": "get_weather", "arguments": {"location": "Paris"}}{"tool": "get_weather", "arguments": {"location": "London"}}
#
# ======================================================================
# [Test 6/10]
# 질문: Multi-agent orchestration의 best practice는?
# 예상 경로: Research Executor (베스트 프랙티스)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 8025.6 ms
#
# 📝 Workflow 응답:
# 📚 [RAG-based Answer]
#
# Multi-agent orchestration involves coordinating multiple AI agents to work together effectively within a system. Here are some best practices derived from the knowledge base:
#
# 1. **Tool Call Management**: In a multi-agent architecture, it's crucial to define how agents will interact with tools and other agents. This requires handling tool calls effectively. For instance, the use of tool calls involves a loop checking for actions that require intervention and following through with necessary function calls, such as calling a Researcher Agent API when needed ([Result 2]).
#
# 2. **Agent Definition and Initialization**: When building agents, especially within Azure AI Foundry, using the SDK to define and manage agents is a key practice. The SDK provides a structured way to create agents, define their models, and set their operational instructions ([Result 4]). This method ensures consistency and ease of management.
#
# 3. **Adoption of Protocols like MCP**: Using protocols such as the Model Context Protocol (MCP) helps standardize how agents define and interact with tools. MCP provides a schema to outline tool parameters, ensuring that every agent knows how to handle tool interactions consistently ([Result 3]).
#
# 4. **Integration with Scaling Solutions**: Consider deploying agents within environments that support scalability and fault tolerance. For example, using Azure Container Apps which offer serverless hosting, automatic scaling, and built-in load balancing can enhance the deployment efficiency of multi-agent systems ([Result 1]).
#
# By following these practices, developers can enhance the coordination and functionality of multi-agent systems in a seamless and scalable manner.
#
# ======================================================================
# [Test 7/10]
# 질문: San Francisco의 날씨와 Azure AI Agent 개발 방법을 알려주세요
# 예상 경로: Orchestrator Executor (복합 질의)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 8217.4 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# 날씨 정보: {
#   "location": "San Francisco, United States of America",
#   "temperature": "24°C",
#   "feels_like": "25°C",
#   "condition": "Clear",
#   "humidity": "50%",
#   "wind_speed": "13 km/h W",
#   "observation_time": "02:18 AM",
#   "data_source": "wttr.in (real-time weather data)"
# }
#
# 📚 [RAG-based Answer]
#
# Regarding Azure AI Agent development, there are a few key steps and concepts outlined in the search results:
#
# 1. **Retrieval-Augmented Generation (RAG) with Azure AI Search**: This involves using Azure AI's capabilities to perform advanced search operations. Specifically, Azure AI Search supports full-text search, vector search, hybrid search combining both methodologies, and semantic ranking using AI to enhance relevance [Result 2].
#
# 2. **Implementation of RAG**: You can create embeddings from text inputs using OpenAI's embedding models via Azure services. These embeddings can be uploaded to an index, allowing for efficient and meaningful document searches. Here’s a snippet of how to create an embedding:
#
#    ```python
#    from openai import AzureOpenAI
#
#    openai_client = AzureOpenAI(
#        api_key=os.getenv("AZURE_OPENAI_API_KEY"),
#        api_version="2024-02-01",
#        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
#    )
#
#    def get_embedding(text: str) -> list:
#        response = openai_client.embeddings.create(
#            model="text-embedding-3-large",
#            input=text
#        )
#        return response.data[0].embedding
#    ```
#
#    After creating embeddings, you can index documents with both text and vector fields for search operations [Result 1].
#
# 3. **Creating Search Indexes**: You can establish search indexes in Azure that support text and vector fields, allowing for complex searches utilizing algorithms such as Hnsw, which is configured for optimal search performance [Result 4].
#
# If you want to explore more about creating effective Azure AI solutions or need further assistance with specific steps in the process, feel free to ask!
#
# As for the current weather in San Francisco, this information isn't available in the knowledge base search results. You might need to consult a real-time weather information source for that.
#
# ======================================================================
# [Test 8/10]
# 질문: 베이징의 날씨는 어떤가요?
# 예상 경로: Tool Executor (베이징 날씨)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 6489.4 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# 날씨 정보: {
#   "location": "Beijing, China",
#   "temperature": "20°C",
#   "feels_like": "20°C",
#   "condition": "Sunny",
#   "humidity": "64%",
#   "wind_speed": "4 km/h SSW",
#   "observation_time": "03:20 AM",
#   "data_source": "wttr.in (real-time weather data)"
# }
#
# ======================================================================
# [Test 9/10]
# 질문: Agent Framework의 Workflow Pattern이란?
# 예상 경로: Research Executor (Framework 개념)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 10894.9 ms
#
# 📝 Workflow 응답:
# 📚 [RAG-based Answer]
#
# The search results do not specifically mention "Agent Framework의 Workflow Pattern" directly. However, some insights related to multi-agent architectures within Azure AI Foundry, which is a context where workflows could be applicable, are found.
#
# 1. **Multi-Agent Architecture in Azure AI Foundry**: This involves implementing Connected Agents where a Main Agent handles tool calls in a loop. For example, a Main Agent continuously checks if an action is required by interrogating the run status. It then processes tool calls through appropriate agents like a Researcher Agent [Result 1].
#
# 2. **Tool Definition in Model Context Protocol (MCP)**: Tools in MCP follow a standardized schema allowing for structured workflows where tools and parameters are well-defined, facilitating predictable interactions between agents and tools [Result 2].
#
# 3. **Creating Vector Stores**: A critical component in agent workflows within Azure AI Foundry involves setting up vector stores for knowledge management. This process supports agent workflows by providing information retrieval capabilities [Result 3].
#
# These components suggest that agent workflows in such frameworks focus on managing interactions through standardized protocols, handling tool calls, and deriving actions based on task requirements. While "Workflow Pattern" isn't explicitly described, the architecture seems to emphasize systematic task management and execution through defined interfaces and continuous monitoring.
#
# For a more specific understanding of "Workflow Pattern" in the context of agent frameworks, further detailed documentation or targeted search queries might be necessary.
#
# ======================================================================
# [Test 10/10]
# 질문: 시드니의 날씨와 Connected Agent 패턴을 설명해주세요
# 예상 경로: Orchestrator Executor (날씨 + 패턴)
# ======================================================================
#
# ✅ 응답 성공 (HTTP 200) - 8043.3 ms
#
# 📝 Workflow 응답:
# 🔧 [Tool Agent]
# 날씨 정보: {
#   "location": "Kirribilli, Australia",
#   "temperature": "17°C",
#   "feels_like": "17°C",
#   "condition": "Overcast",
#   "humidity": "83%",
#   "wind_speed": "5 km/h NNE",
#   "observation_time": "12:01 AM",
#   "data_source": "wttr.in (real-time weather data)"
# }
#
# 📚 [RAG-based Answer]
#
# Unfortunately, specific weather information for Sydney is not available in the search results, as the provided content primarily focuses on AI Agent development patterns and architecture.
#
# Regarding the Connected Agent pattern, the search results discuss its role within a multi-agent architecture, as implemented in the Azure AI Foundry. Connected Agents are designed to work together to solve complex problems. They utilize a main agent that coordinates specialized agents, enabling them to perform tasks that require multiple competencies or data sources.
#
# For example, in Azure AI Foundry, you might create a main agent that communicates with a researcher agent through function tools. This setup involves setting up toolsets and defining function tools, such as `call_researcher_agent`, which allows the main agent to perform specific actions like researching information using an AI search knowledge base [Result 3].
#
# Additionally, these agents often rely on connected systems like a vector store to manage a database of knowledge, making them efficient at retrieving and processing information using services like Azure AI Search with appropriate authentication setups [Result 4].
#
# In summary, Connected Agents are part of a sophisticated architecture pattern that allows various agents to collaborate efficiently, with orchestration handled by a main agent which communicates with specialized agents to complete complex tasks [Results 2, 3, 4].
#
# ======================================================================
#
# 📊 테스트 결과:
#    ✅ 성공: 10/10
#    ❌ 실패: 0/10
#    ⏱️  평균 지연: 9838.8 ms (p95≈16927.8 ms)
#
# 🎉 10개의 Workflow 실행이 성공했습니다!
#
# ⚠️  참고: Agent Framework는 OpenTelemetry가 구현되지 않아
#    AI Foundry Analytics/Tracing에 데이터가 수집되지 않습니다.
#    디버깅은 컨테이너 로그를 통해 확인하세요:
#    az containerapp logs show --name agent-framework --resource-group rg-aiagent-ciid4s --tail 50
#
# ======================================================================

# %% [markdown]
# ## 7. 정리 및 비교 (Summary & Comparison)
#
# ### Foundry Agent vs Agent Framework 비교
#
# #### 아키텍처 패턴
#
# **Foundry Agent (Lab 3):**
# ```
# Main Agent
#   └─> handoff_to_tool_agent()
#         └─> Tool Agent executes
#               └─> returns to Main Agent
#   └─> handoff_to_research_agent()
#         └─> Research Agent executes
#               └─> returns to Main Agent
# ```
#
# **Agent Framework (Lab 4):**
# ```
# Router Executor
#   └─> send_message(target="tool")
#         └─> Tool Executor executes
#               └─> yield_output()
#   └─> send_message(target="orchestrator")
#         └─> Orchestrator runs Tool + Research in parallel
#               └─> asyncio.gather()
#                     └─> yield_output(combined)
# ```
#
# #### 장단점 비교
#
# | 특성 | Foundry Agent | Agent Framework |
# |------|--------------|----------------|
# | **관리형 서비스** | ✅ Azure 완전 관리 | ❌ 코드 직접 관리 |
# | **Thread 상태** | ✅ 자동 유지 | ❌ 수동 관리 |
# | **병렬 실행** | ❌ Handoff는 순차적 | ✅ asyncio.gather() |
# | **유연성** | ⚠️ Azure API 제약 | ✅ 완전한 제어 |
# | **로컬 개발** | ⚠️ Azure 의존성 | ✅ 독립 실행 가능 |
# | **프로덕션 준비** | ✅ 엔터프라이즈급 | ⚠️ 추가 구현 필요 |
#
# #### 사용 권장 시나리오
#
# **Foundry Agent 선택:**
# - Azure 생태계에 깊이 통합된 솔루션
# - 엔터프라이즈급 관리형 서비스 필요
# - Thread 기반 대화 컨텍스트 자동 관리
# - 빠른 프로토타이핑과 배포
#
# **Agent Framework 선택:**
# - 세밀한 실행 흐름 제어 필요
# - 복잡한 병렬 처리 패턴
# - 커스텀 오케스트레이션 로직
# - 로컬 개발 및 빠른 반복
#
# ### 실습 완료! 🎉
#
# **학습 내용 요약:**
# 1. ✅ Microsoft Agent Framework Workflow Pattern 이해
# 2. ✅ Executor 기반 Multi-Agent 구현 및 배포
# 3. ✅ Workflow Context 메시지 라우팅
# 4. ✅ Parallel execution (Orchestrator) 패턴
# 5. ✅ Foundry Agent와 Framework 비교 분석
#
# **다음 단계:**
# - Application Analytics 및 Tracing 데이터 분석
# - 커스텀 Executor 추가 실험
# - 두 패턴의 성능 및 비용 비교
# - 프로덕션 환경 적용 고려사항 검토
